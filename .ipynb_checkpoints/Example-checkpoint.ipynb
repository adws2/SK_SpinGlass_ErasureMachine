# %% [markdown]
# $J^{n+1}_{ij} \approx J^{n}_{ij} + \alpha (\left\langle s_i s_j \right\rangle^{f_\epsilon} -  \epsilon J^{n}_{ij} -\lambda J^{n}_{ij}$

# %%
from Erasure_machine import fit
from Sampler import simulater
from Spin_calculator import calculator

import matplotlib.pyplot as plt
import numpy as np
import torch
import time

# %% [markdown]
# ## model : 2D-Ising model

# %%
T = np.arange(3.5,1.0,-0.1)
eq_T = 1000
K = 5
M = 1000

N = 25

sampler =  simulater(N, M, T, eq_T, K)
sampler.adjacency_matrix('2D-Ising')

# %%
start = time.time()
samples = sampler.MC_Sampling()
np.save('Test_samples/2D_Ising_config_N%d.npy'%N, samples)
print('obtain samples during ', time.time() - start)
# Out:
# obtain samples during  81.0001528263092

# %%
calcul = calculator(samples)
J = sampler.J

plt.figure(figsize = (10,6))

M = calcul.magnetization()
plt.subplot(2,2,1)
plt.ylabel('$M$')
plt.xlabel(r'$T$')
plt.plot(T,M)

X = calcul.susceptibility(T)
plt.subplot(2,2,2)
plt.ylabel(r'$\chi$')
plt.xlabel(r'$T$')
plt.plot(T,X)

E = calcul.energy(J)
plt.subplot(2,2,3)
plt.ylabel('$E$')
plt.xlabel(r'$T$')
plt.plot(T,E)

C = calcul.Specific_heat(T, J)
plt.subplot(2,2,4)
plt.ylabel(r'$C_v$')
plt.xlabel(r'$T$')
plt.plot(T,C)
plt.savefig('image/2D_Ising_measurements_N%d.png'%N)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### inference

# %%
solver = fit()
# Out:
# Use cuda

# %%
MSE_arr = np.zeros(len(T))
start = time.time()
w_true = solver.J_to_w(sampler.J).to('cuda')

for i,t in enumerate(T):
    config = samples[:,:,i]
    ops = solver.operators(config)
    w_infer = solver.em(ops, L1 = 0.1)
    MSE_arr[i] = torch.sum((w_infer - w_true)**2) / torch.sum((w_true)**2)
    
print('obtain coupling during ', time.time() - start)

plt.plot(T,MSE_arr)
plt.ylabel(r'$\Delta$')
plt.xlabel(r'T')
plt.savefig('image/2D_Ising_EM_N%d.png'%N)
plt.show()
# Out:
# obtain coupling during  2.0388829708099365

# %% [markdown]
# # SK model

# %%
T = np.arange(1.5,0.1,-0.05)
eq_T = 1000
K = 5
M = 1000

N = 25

sampler =  simulater(N, M, T, eq_T, K)
sampler.adjacency_matrix('SK-model')

# %%
start = time.time()
samples = sampler.MC_Sampling()
np.save('Test_samples/SK_model_config_N%d.npy'%N, samples)
print('obtain samples during ', time.time() - start)
# Out:
# obtain samples during  92.59146022796631

# %%
calcul = calculator(samples)
J = sampler.J

plt.figure(figsize = (10,5),constrained_layout=True)
q = calcul.Edward_Anderson()
plt.subplot(1,2,1)
plt.ylabel('$q$')
plt.xlabel('$T$')
plt.plot(T,q)

X = calcul.SG_susceptibility()
plt.subplot(1,2,2)
plt.ylabel(r'$\chi_{SG}$')
plt.xlabel('$T$')
plt.plot(T,X)
plt.savefig('image/SK_model_measurements_N%d.png'%N)
plt.show()

# %% [markdown]
# ### inference

# %%
solver = fit()
# Out:
# Use cuda

# %%
MSE_arr = np.zeros(len(T))
start = time.time()
w_true = solver.J_to_w(sampler.J).to('cuda')

for i,t in enumerate(T):
    config = samples[:,:,i]
    ops = solver.operators(config)
    w_infer = solver.em(ops, L2 = 0.1)
    MSE_arr[i] = torch.sum((w_infer - w_true)**2) / torch.sum((w_true)**2)
    
print('obtain coupling during ', time.time() - start)

plt.plot(T,MSE_arr)
plt.ylabel(r'$\Delta$')
plt.xlabel(r'T')
plt.yscale('log')
plt.savefig('image/SK_model_EM_N%d.png'%N)
plt.show()
# Out:
# obtain coupling during  0.6217551231384277
